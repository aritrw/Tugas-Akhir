# %% [markdown]
# Library yang akan digunakan

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# Load Dataset

# %%
stunting_dataset = pd.read_csv('Dataset_Skripsii.csv')

# %%
stunting_dataset.head()
# Out:
#    Usia Jenis_Kelamin  BB_Lahir  TB_Lahir  BB_Sekarang  TB_Sekarang  LiLA  \
# 0     0     Laki-laki      2.90        49         2.90         49.0  16.0
# 1     0     Laki-laki      2.40        42         3.30         52.0  15.0
# 2     0     Perempuan      2.70        48         2.70         48.0  14.0
# 3     1     Laki-laki      3.58        50         4.31         54.0  17.0
# 4     1     Perempuan      2.25        48         4.00         51.0  15.0
#
#   Stunting
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No

# %%
stunting_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1784 entries, 0 to 1783
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Usia           1784 non-null   int64
#  1   Jenis_Kelamin  1784 non-null   object
#  2   BB_Lahir       1784 non-null   float64
#  3   TB_Lahir       1784 non-null   int64
#  4   BB_Sekarang    1784 non-null   float64
#  5   TB_Sekarang    1784 non-null   float64
#  6   LiLA           1784 non-null   float64
#  7   Stunting       1784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 111.6+ KB

# %%
from IPython.display import display
display(stunting_dataset)
# Out:
#       Usia Jenis_Kelamin  BB_Lahir  TB_Lahir  BB_Sekarang  TB_Sekarang  LiLA  \
# 0        0     Laki-laki      2.90        49         2.90         49.0  16.0
# 1        0     Laki-laki      2.40        42         3.30         52.0  15.0
# 2        0     Perempuan      2.70        48         2.70         48.0  14.0
# 3        1     Laki-laki      3.58        50         4.31         54.0  17.0
# 4        1     Perempuan      2.25        48         4.00         51.0  15.0
# ...    ...           ...       ...       ...          ...          ...   ...
# 1779    60     Laki-laki      3.10        48        19.20        103.0  15.0
# 1780    60     Laki-laki      3.10        48        13.10        101.0  15.0
# 1781    60     Laki-laki      3.40        49        17.80        109.0  17.0
# 1782    60     Laki-laki      3.50        48        18.80        115.0  15.0
# 1783    60     Perempuan      3.50        49        15.30         95.2  16.0
#
#      Stunting
# 0          No
# ...

# %%
stunting_dataset.shape
# Out:
# (1784, 8)

# %%
duplikat_kolom = stunting_dataset[
    stunting_dataset.duplicated(
        subset=["Usia", "Jenis_Kelamin", "BB_Lahir", "TB_Lahir",
                "BB_Sekarang", "TB_Sekarang","LiLA", "Stunting"]
    )
]

if duplikat_kolom.empty:
    print("Tidak ada data duplikat berdasarkan kolom yang dipilih.")
else:
    print("Data duplikat ditemukan:")
    print(duplikat_kolom)
# Out:
# Tidak ada data duplikat berdasarkan kolom yang dipilih.

# %% [markdown]
# Pengecekan Missing Value

# %%
stunting_dataset.isnull().sum()
# Out:
# Usia             0
# Jenis_Kelamin    0
# BB_Lahir         0
# TB_Lahir         0
# BB_Sekarang      0
# TB_Sekarang      0
# LiLA             0
# Stunting         0
# dtype: int64

# %% [markdown]
# Label Encoding

# %%
stunting_dataset['Jenis_Kelamin'] = stunting_dataset['Jenis_Kelamin'].replace({'Laki-laki':1,'Perempuan':0})
stunting_dataset['Stunting'] = stunting_dataset['Stunting'].replace({'No':0,'Yes':1})

# %%
# memisahkan data dan label
X = stunting_dataset.drop (columns='Stunting', axis=1)
Y = stunting_dataset['Stunting']

# %%
print(X)
# Out:
#       Usia  Jenis_Kelamin  BB_Lahir  TB_Lahir  BB_Sekarang  TB_Sekarang  LiLA
# 0        0              1      2.90        49         2.90         49.0  16.0
# 1        0              1      2.40        42         3.30         52.0  15.0
# 2        0              0      2.70        48         2.70         48.0  14.0
# 3        1              1      3.58        50         4.31         54.0  17.0
# 4        1              0      2.25        48         4.00         51.0  15.0
# ...    ...            ...       ...       ...          ...          ...   ...
# 1779    60              1      3.10        48        19.20        103.0  15.0
# 1780    60              1      3.10        48        13.10        101.0  15.0
# 1781    60              1      3.40        49        17.80        109.0  17.0
# 1782    60              1      3.50        48        18.80        115.0  15.0
# 1783    60              0      3.50        49        15.30         95.2  16.0
#
# [1784 rows x 7 columns]

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1779    0
# 1780    0
# 1781    0
# 1782    0
# 1783    1
# Name: Stunting, Length: 1784, dtype: int64

# %% [markdown]
# Standarisasi Data

# %%
scaler = StandardScaler()
scaler.fit(X)
standarized_data = scaler.transform(X) 
X = standarized_data
Y = stunting_dataset['Stunting'] 
print(X)
print(Y)
# Out:
# [[-2.46717671  0.85854432 -0.19020457 ... -0.07239806 -3.49146991
#    0.19010128]
#  [-2.46717671  0.85854432 -0.56025882 ... -0.07021973 -3.21910515
#   -0.14789023]
#  [-2.46717671 -1.16476224 -0.33822627 ... -0.07348722 -3.58225816
#   -0.48588175]
#  ...
#  [ 1.72907008  0.85854432  0.17984968 ...  0.00874442  1.95582528
#    0.5280928 ]
#  [ 1.72907008  0.85854432  0.25386054 ...  0.01419023  2.5005548
#   -0.14789023]
#  [ 1.72907008 -1.16476224  0.25386054 ... -0.00487009  0.70294739
#    0.19010128]]
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1779    0
# 1780    0
# 1781    0
# 1782    0
# 1783    1
# Name: Stunting, Length: 1784, dtype: int64

# %% [markdown]
# Memisahkan Data Training dan Data Testing

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.3, stratify=Y, random_state=42)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1784, 7) (1248, 7) (536, 7)

# %%
from sklearn.model_selection import GridSearchCV

# Inisialisasi model SVM
svm_model = SVC(probability=True, random_state=42)

# Parameter grid untuk dicoba
param_grid = {
    'C': [0.1, 1, 10, 100],             # regularisasi
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],  # jenis kernel
}

grid_search = GridSearchCV(
    estimator=svm_model,
    param_grid=param_grid,
    cv=5,            # 5-fold cross validation
    n_jobs=-1,       # pakai semua core CPU
    verbose=2,       # tampilkan progres
    scoring='accuracy'  # metrik evaluasi
)

# Jalankan pencarian grid
grid_search.fit(X_train, Y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Parameters: {'C': 100, 'kernel': 'rbf'}
# Best Accuracy: 0.9431100401606425

# %% [markdown]
# Membuat data latih menggunakan algoritma Random Forest

# %%
model_svm = SVC(C=100, kernel='rbf', random_state=42)
model_svm.fit(X_train, Y_train)
# Out:
# SVC(C=100, random_state=42)

# %% [markdown]
# Membuat model evaluasi untuk mengukur tingkat akurasi

# %%
sv = model_svm.predict(X_train)
training_data_accuracy = accuracy_score(sv,Y_train)
print('Akurasi data training adalah =', training_data_accuracy)


sv = model_svm.predict(X_test)
test_data_accuracy = accuracy_score(sv,Y_test)
print('Akurasi data testing adalah =', test_data_accuracy)
# Out:
# Akurasi data training adalah = 0.9735576923076923
# Akurasi data testing adalah = 0.9347014925373134

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score


y_pred = model_svm.predict(X_test)

akurasi = accuracy_score(Y_test, y_pred)
presisi = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)

print(f"Akurasi: {akurasi:.4f}")
print(f"Presisi: {presisi:.4f}")
print(f"Recall : {recall:.4f}")
print(f"F1-Score: {f1:.4f}")


print("\nClassification Report:")
print(classification_report(Y_test, y_pred))
# Out:
# Akurasi: 0.9347
# Presisi: 0.9173
# Recall : 0.9494
# F1-Score: 0.9331
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       279
#            1       0.92      0.95      0.93       257
#
#     accuracy                           0.93       536
#    macro avg       0.93      0.94      0.93       536
# weighted avg       0.94      0.93      0.93       536

# %% [markdown]
# Membuat model deteksi

# %%
input_data = (7,1,3.8,49,28,14, 72.2)

input_data_as_numpy_array = np.array(input_data)

input_data_reshape = input_data_as_numpy_array.reshape(1,-1)

std_data = scaler.transform(input_data_reshape)
print(std_data)

prediction = model_svm.predict(std_data)
print(prediction)

if (prediction[0] == 0):
    print('Anak tidak berisiko stunting')
else :
    print('Anak berisiko stunting')
# Out:
# [[-1.97761459  0.85854432  0.47589309  0.60042991  0.06429162 -6.66905877
#   19.18522445]]
# [0]
# Anak tidak berisiko stunting
# c:\Users\aritr\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Simpan model

# %%
#import pickle
#pickle.dump(model_svm, open('stunting.sav', 'wb'))
#pickle.dump(scaler, open('scaler.sav', 'wb'))
